# %% [markdown]
# operators

# %%
a = 2
b = 3
a + b # arithematic operator
# Out:
# 5

# %%
add = a + b # addition operator
add
# Out:
# 5

# %%
100 - 3 # substraction operator
# Out:
# 97

# %%
3 * 5 # multiplication operator
# Out:
# 15

# %%
21 / 4 # division operator
# Out:
# 5.25

# %%
# Modulus operator (Remainder)
21 % 4
# Out:
# 1

# %%
2 ** 3  # 2 to power 3
# Out:
# 8

# %%
4 / 3
# Out:
# 1.3333333333333333

# %%
4 // 2 # floor operator
# Out:
# 2

# %%
# comparision operator >> compare two values >> return a boolean.
2 == 2
# Out:
# True

# %%
2 != 2
# Out:
# False

# %%
12 >= 5
# Out:
# True

# %%
5 != 2
# Out:
# True

# %%
10 > 2
# Out:
# True

# %%
12 >= 12
# Out:
# True

# %%
10 >= 2
# Out:
# True

# %%
10 < 2
# Out:
# False

# %%
10 <= 10
# Out:
# True

# %%
# logical operator
# And
# or
True - False
# Out:
# 1

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
# not operator
not False
# Out:
# True

# %%
not False
# Out:
# True

# %%
# Assign operator
a = 10
a
# Out:
# 10

# %%
a + 5
# Out:
# 15

# %%
b = 10
b + 6
# Out:
# 16

# %%
b = 12
b = b + 6
b
# Out:
# 18

# %%
b = 12
b -= 5
b
# Out:
# 7

# %%
b *= 2
b
# Out:
# 14

# %%
b /= 3
b
# Out:
# 4.666666666666667

# %%
# membership operator
a = "pwskills"
"p" in a
# Out:
# True

# %%
"p" not in a
# Out:
# False

# %%
b = "yuvraj"
"as" in b
# Out:
# False

# %%
"aj" in b
# Out:
# True

# %%
a = ["data","analytics","science","data"]
"yuvraj" in a
# Out:
# False

# %%
# Identity operators  >> compares the location of two object/variable
a = 2
b = 3
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
a = 2
b = a
a is b
# Out:
# True

# %%
# order of precedence
# execution of python statement will be from left to right
b = 5
b += 8
b
# Out:
# 13

# %%
2 + 3 - 8
# Out:
# -3

# %%
# Always parenthesis first
(5+3)-4
# Out:
# 4

# %%
4-(3+5)
# Out:
# -4

# %%
(10+5)+(8/2)
# Out:
# 19.0
