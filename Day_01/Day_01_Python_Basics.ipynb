# %% [markdown]
# # Predefined keywords

# %%
a = "Hello world"
a
# Out:
# 'Hello world'

# %%
b = 4.5
b
type(b)
# Out:
# float

# %%
c = "yuvraj"
c
type(c)
# Out:
# str

# %%
c = True
type(c)
# Out:
# bool

# %%
True - False
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
True/False # Error 1 divided 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2794436645.py in <cell line: 0>()
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
f = None
f
type(f)
# Out:
# NoneType

# %%
# x+iy >> complex number
com = 5 + 6j
type(com)
# Out:
# complex

# %%
com.real
# Out:
# 5.0

# %%
com.imag
# Out:
# 6.0

# %%
# Rules of defining a variable >> A variable start with a letter(alphabet) or underscore character, it should not be keywords

# %%
# invalid ways
5 = a # error , cannot start with integer
2.3 = b # error , cannot start with float
1name = "Ram" # error
1 = abc # error
data analytics course = "pwskills" # error
@abc = 2.3 # error
# %abc = "ram" # error
# Out:
#   File "/tmp/ipython-input-3205076172.py", line 4
#     1name = "Ram" # error
#     ^
# SyntaxError: invalid decimal literal

# %%
# valid ways
name = "Ram"
name
# Out:
# 'Ram'

# %%
location = "Bihar"
location
# Out:
# 'Bihar'

# %%
_name = "Rahul"
_name
# Out:
# 'Rahul'

# %%
data_analytics_course = "pwskills"
data_analytics_course
# Out:
# 'pwskills'

# %%
# comments
# This is my first comments
# This is my second comments

''' This is a multi line comments
I am a student of data science
and enjoying study'''

""" My name is yuvraj chaudhary
my first day of learning data science """

# %%
# keywords >> are predefined words that hold a special meaning and have specific purpose in python progamming
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
#indentation >> more readable
if 3 > 2:
  print("greater")
# Out:
# greater

# %%
# statement can be of many types >> expression, assignment, condition statement, loop
a = 5 # assignment statement
a
# Out:
# 5

# %%
a + b # expression statement
# Out:
# 9.5

# %%
# input output >> if you want some user to give of variable
name = input("please enter your name")
name
# Out:
# please enter your nameyuvraj chaudhary
# 'yuvraj chaudhary'

# %%
type(name)
# Out:
# str

# %%
# Input actually take every value as a string
# we can convert '2' as int
# Type casting >> cast means to change the format
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2788706382.py in <cell line: 0>()
#       2 # we can convert '2' as int
#       3 # Type casting >> cast means to change the format
# ----> 4 int('yuvraj')
#
# ValueError: invalid literal for int() with base 10: 'yuvraj'

# %%
a = "3.5"
type(a)
# Out:
# str

# %%
type(float(a))
# Out:
# float

# %%
s = "108"
type(s)
# Out:
# str

# %%
int(s)
# Out:
# 108

# %%
float(s)
# Out:
# 108.0

# %%
str(s)
# Out:
# '108'

# %%
# python is case sensitive programming language
a = 5
A = 15
a
A
# Out:
# 15

# %%
# variable should not be keywords
print("hello")
print("yuvraj")
print("world")
# Out:
# hello
# yuvraj
# world

# %%
# Mutability and Immutability
'''objects/container whose state or value can be changed after they are created are called as mutable objects/container,also called as item asignment.
 list is a type of mutable object/support item assignment '''

# %%
'''objects/container whose state or value cannot be changed after they are created are called as immutable object or container.
 string is called immutable object, does not support item assignment .'''
