# %% [markdown]
# CONDITIONALS

# %%
# conditionals >> I will play cricket when the weather is sunny

# %%
# Loop statement >> I will keep checking out dishes until all the dishes are over in a buffet.

# %%
# I will keep check out all the dishes until I get pasta

# %%
# conditional statement >> helps you to code decisions based on some preconditions
# if
# if else
# if elif(elseif)else
# nested if else

# %%
a = 100
if a > 0: # execute if block, if condition is True
  print("The number is greater than 0")
# Out:
# The number is greater than 0

# %%
a = 100
if a < 0:
  print("The number is greater than 0")

# %%
weather = "rainy"
if weather == "rainy":
  print("I will not play cricket")
# Out:
# I will not play cricket

# %%
weather = "sunny"
if weather == "rainy":
  print("I will not play cricket")

# %%
temperature = 30
if temperature > 25:
  print("room temperature")
# Out:
# room temperature

# %%
is_ds_course = True
if is_ds_course:
  print("I am studying the course")
# Out:
# I am studying the course

# %%
grade = 8
if grade >= 8:
  print("you are excellent")
# Out:
# you are excellent

# %%
number = 42
if number % 2 == 0:
  print("The number is even")
# Out:
# The number is even

# %%
# In real life, decisions are made based on multiple conditions
number = 42
if ((number % 2 == 0) & (number > 0)):
  print("This is number of interest")
# Out:
# This is number of interest

# %%
from os import name
grade = 8
if ((grade >= 8) & (name == True)):
  print("you are all rounder")

# %%
# In real life if one condition is not fullfilled, you will do something else
# example: if weather is not rainy, I will go to play cricket else I will watch TV
# if else >> execute the if block when the condition is True else execute else block

# %%
weather = "rainy"
if weather == "rainy":
  print("I will not play cricket")
else:
    print("I will watch TV")
# Out:
# I will not play cricket

# %%
age = 21
if age >= 18:
  print("you will be served alcohol")
else:
  print("get out of the bar")
# Out:
# you will be served alcohol

# %%
age = 19
if age >= 18:
  print("please have a driving license and drive")
else:
  print("dont drive")
# Out:
# please have a driving license and drive

# %%
is_ds_course = True
if is_ds_course:
  print("I am studying")
else:
  print("I am playing cricket")
# Out:
# I am studying

# %%
x = 16
if x > 5:
  print("x is greater than 5")
else:
  print("The number is less than 5")
# Out:
# x is greater than 5

# %%
# to check if a number is even
6 % 2
# Out:
# 0

# %%
if number == 4 % 2 == 0:
  print("even")
else:
  print("odd")
# Out:
# odd

# %%
score = 33
if score >= 33:
  print("you are passed")
else:
  print("repeat the class")
# Out:
# you are passed

# %%
# if else >> two condition
# In real life we can have multiple condition.
# syntax
# if some condition
# elif some condition
# else

# %%
a = 10
if a > 100:
  print("This block will be executed if a is greater than 100")
elif a < 100:
  print("This block will be executed if a is lesser than 100")
else:
  print("The number is equals to 100")
# Out:
# This block will be executed if a is lesser than 100

# %%
a = 100000
if a < 100:
  print("This block will be executed if a is greater than 100 if a is greater than 100")
elif a > 2000:
  print("The number is huge")
elif a > 100:
  print("This block will be executed if a is greater than 100")
else:
  print("The number is equals to 100")
# Out:
# The number is huge

# %%
score = 80
if score >= 90:
  print("grade A")
elif (80 <= score < 90):
  print ("grade B")
elif(70 <= score < 80):
  print("grade C")
else:
  print("grade D")
# Out:
# grade B

# %%
age = 30
if age < 18:
  print("you are minority")
elif (18 < age <= 65):
  print("you are adult")
else:
  print("you are senior citizen")
# Out:
# you are adult

# %%
# nested if else >> you can have multiple if else inside if else
x = 1
y = 6
if x > 5:
  if y > 5:
    print("both x and y is greater than 5")
  else:
    print("x is greater than 5 but y is less than 5")
else:
  print("x is not greater than 5")
# Out:
# x is not greater than 5

# %%
is_vip = True
age = 70
if is_vip:
    if age >= 18:
        if age < 65:
            print("welcome to vip customer")
        else:
            print("you are vip and very imp. you are eligible for senior citizen discount")
    else:
        print("vip status is only for adult")
else:
    print("you are not a vip customer and will be charged a regular price")
# Out:
# you are vip and very imp. you are eligible for senior citizen discount

# %%
a = input ("enter a number")
print("The number is a")
# Out:
# enter a number100
# The number is a

# %%
type(a)
# Out:
# str

# %%
a = int(input("enter a number"))
a
# Out:
# enter a number800
# 800

# %%
type(a)
# Out:
# int

# %%
a = int(input("enter a number"))
if a >= 100:
  print("The number is greater than 100")
elif 0 <= a < 100:
  print("The number is greater than 0 and less than 100")
else:
  print("This is a negative number")
# Out:
# enter a number900
# The number is greater than 100

# %%
name = input ("Please enter your name")
email = input ("please enter your email")
password = input("please enter your password")
if name == " ":
  print("please enter a valid name, can not be empty")
else:
  if "@" not in email:
    print("please enter a valid email")
  else:
    if len(password) < 0:
      print("No password entered, please provide a valid password")
    else:
      print("login/registration is successful")
