# %% [markdown]
# TYPE CASTING

# %%
a = 5
type(a)
# Out:
# int

# %%
b = 5.6
type(b)
# Out:
# float

# %%
a ="yuvraj"
a
type(a)
# Out:
# str

# %%
2+3
# Out:
# 5

# %%
"2"+3 # It will throw an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-444662051.py in <cell line: 0>()
# ----> 1 "2"+3
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Type casting/Type conversion >> The process of changing the data type of a value/object
# why? while executing/computation using operators there can be mismatch between the data.

# %%
a ="2"
b = 3
a+b # error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-284437783.py in <cell line: 0>()
#       1 a ="2"
#       2 b = 3
# ----> 3 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
type(a)
# Out:
# str

# %%
a = "2"
b = 3
int(a)+b
# Out:
# 5

# %%
# string to integer
a ="2"
print(type(a))
# Out:
# <class 'str'>

# %%
a = 3.4
type (a)
# Out:
# float

# %%
int(a)
# Out:
# 3

# %%
b = 6.78
type(b)
# Out:
# float

# %%
float_value = int(b)
type(float_value)
# Out:
# int

# %%
#integer to float
a = 2
type(a)
# Out:
# int

# %%
b = float(a)
b
# Out:
# 2.0

# %%
# string to float
a = "2.3"
type(a)
# Out:
# str

# %%
b = float(a)
type(b)
# Out:
# float

# %%
a = "yuvraj"
type(a)
# Out:
# str

# %%
int(a) # character cannot be converted into numbers
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-766485689.py in <cell line: 0>()
# ----> 1 int(a)
#
# ValueError: invalid literal for int() with base 10: 'yuvraj'

# %%
# int to str
a = 5
type(a)
# Out:
# int

# %%
c = str(a)
c = 5
type(c)
# Out:
# int

# %%
# Type casting >> implicit and explicit
# implicit typecasting >> python understand the data type
a = 5
type(a)
# Out:
# int

# %%
2+3.5
# Out:
# 5.5

# %%
# Explicit type casting >> convert data type using inbuilt functiond >> str, int, float, bool#
a = "2"
type(a)
# Out:
# str

# %%
int(a)
# Out:
# 2

# %%
float(a)
# Out:
# 2.0

# %%
2+3
# Out:
# 5

# %%
a = "yuvraj"
b = 5
a+b #error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2316709645.py in <cell line: 0>()
#       1 a = "yuvraj"
#       2 b = 5
# ----> 3 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = "yuvraj"
b = " chaudhary"
a + b # concatenation of string combine the string
# Out:
# 'yuvraj chaudhary'

# %%
"maths" + " science"
# Out:
# 'maths science'

# %%
"100" + " yuvraj"
# Out:
# '100 yuvraj'

# %%
# bool
bool(0)
# Out:
# False

# %%
bool(1) #above number more than 1 treated as true
# Out:
# True

# %%
bool(1000)
# Out:
# True

# %%
bool("yuvraj")
# Out:
# True

# %%
bool("class")
# Out:
# True

# %%
bool("") #empty string
# Out:
# False

# %%
bool(-5)
# Out:
# True
