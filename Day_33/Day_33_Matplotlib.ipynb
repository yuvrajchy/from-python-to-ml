# %%
#why do we need visualisation? #summarisation of data
#matplotlib, seaborn, plotly, bokeh
#matplotlib>> Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore') #suppress all the warnings

# %%
#line, scatter, bar, histogram, pie chart, box plot, violin plot

# %%
#generate random numbers in numpy
x = np.random.rand(50)

# %%
len(x)
# Out:
# 50

# %%
np.random.randn(50)
# Out:
# array([ 0.06340999,  0.78644997,  0.19828152, -0.75575961, -0.23089578,
#        -2.72476804, -0.32705224, -0.54447858,  2.52856887, -0.90842647,
#        -0.55336068, -0.18362343, -1.14867552, -0.09183447,  1.03003785,
#        -0.49988065,  1.85663207,  0.62602568,  0.91962145,  0.79499722,
#        -0.37056028, -1.122464  , -0.88518888, -1.76979732,  0.40702964,
#         0.47870318,  1.03416075,  0.68098727, -1.11637571,  0.94430801,
#         0.75920835,  0.71806602,  0.16199946,  1.6179244 , -1.60343454,
#         1.57556446, -1.84340135,  1.05035208,  1.00593533, -0.30544911,
#         1.88789286, -0.65138012,  0.12366402, -1.18818883, -0.92696608,
#         1.33302956,  0.474152  ,  0.11256674, -1.17992526,  2.46479825])

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ['Data'], index = pd.date_range('2024-07-11', periods = 1000))

# %%
df
# Out:
#                 Data
# 2024-07-11 -0.230286
# 2024-07-12  1.274675
# 2024-07-13  0.345372
# 2024-07-14  1.080319
# 2024-07-15 -1.959053
# ...              ...
# 2027-04-02  1.735645
# 2027-04-03 -0.211576
# 2027-04-04  1.799190
# 2027-04-05  1.353670
# 2027-04-06 -0.883197
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20, 8)) #summary>> most of the values are fluctuating between -2 and 2
# Out:
# <Axes: >

# %%
x
# Out:
# array([0.77270936, 0.70846496, 0.51304233, 0.56669483, 0.30533753,
#        0.87229705, 0.641596  , 0.79844666, 0.68295952, 0.27961884,
#        0.04062832, 0.09295544, 0.9090504 , 0.38693908, 0.30587362,
#        0.14032527, 0.10042582, 0.59722447, 0.39703914, 0.0546889 ,
#        0.45778765, 0.35722422, 0.44556336, 0.32508243, 0.52700234,
#        0.52008044, 0.6963645 , 0.64043594, 0.2729964 , 0.58164841,
#        0.43890228, 0.72792779, 0.15893174, 0.39339526, 0.65784885,
#        0.81441294, 0.06717273, 0.87810634, 0.96385076, 0.88121628,
#        0.1149769 , 0.49121083, 0.14987435, 0.38754858, 0.26348227,
#        0.97745832, 0.92477121, 0.35609934, 0.37790445, 0.33319658])

# %%
y = np.random.rand(50)
y
# Out:
# array([0.56856864, 0.14479318, 0.61653753, 0.11159986, 0.42345672,
#        0.59035736, 0.68697805, 0.09076562, 0.87263925, 0.19217364,
#        0.53545995, 0.98675017, 0.51974335, 0.33724697, 0.96797813,
#        0.58873766, 0.92582941, 0.84076851, 0.42593543, 0.57745689,
#        0.20287262, 0.98419301, 0.17127636, 0.87684727, 0.56557781,
#        0.22692919, 0.05877624, 0.15862647, 0.54104214, 0.95673113,
#        0.25251956, 0.90572194, 0.25732604, 0.43775226, 0.20691097,
#        0.40651159, 0.82782694, 0.98637669, 0.18324752, 0.95151212,
#        0.84808995, 0.62672496, 0.79405222, 0.51358248, 0.93303284,
#        0.73486731, 0.08894427, 0.54624166, 0.77338125, 0.14704715])

# %%
#scatter plot >> A scatter plot is a type of data visualization that displays values for two variables as points on a Cartesian plane. Each point represents the value of one variable corresponding to the value of the other variable
plt.scatter(x, y)

# %%
#line plot
#whenever you want to depict the relation between two variables in the form of trend
#mostly in x axis the date - time column is there
x = [1, 2, 3, 4, 5] #assume x is no of day
y = [5, 2, 7, 8, 1] #y is price of stock

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [5, 2, 7, 8, 1]

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
x, y
# Out:
# ([1, 2, 3, 4, 5], [5, 2, 7, 8, 1])

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--')
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4, markersize = 15)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4, markersize = 15)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 1]

plt.plot(x, y1, color = "red", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label="line y1 as tata motors")
plt.plot(x, y2, color = "b", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label="line y2 as tata power")

plt.title("Multiple lines in one plot")

plt.xlabel("Days")
plt.ylabel("stock price")
plt.legend()

plt.show()

# %%
x = np.linspace(0, 10, 100)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x), '--')

# %%
plt.plot(x, np.sin(x), '-')

# %%
plt.plot(x, np.sin(x), '.-')

# %%
plt.plot(x, np.sin(x), ':')

# %%
plt.figure() #initialising a page to make plot
plt.subplot(1, 2, 1)
plt.plot(x, np.sin(x))

plt.subplot(1, 2, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure() #initialising a page to make plot
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))

plt.subplot(2, 2, 3)
plt.plot(x, np.tan(x))

plt.subplot(2, 2, 4)
plt.plot(x, np.sin(x+1))

plt.show()

# %%
plt.plot(x, np.sin(x), color = 'blue')

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.grid()
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.title("basic syntax")
plt.xlabel("x label")
plt.ylabel("y label")
plt.axis('equal')
plt.grid()
plt.show()

# %%
#histogram>> continuous numerical data

data = np.random.randn(1000) #by default 10 bins are created
plt.hist(data)
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data, color = 'r', bins = 20)
plt.show()

# %%
#stacked histogram >> two histograms together
data1 = np.random.normal(0, 1, 5000)
data2 = np.random.normal(3, 2, 5000)

# %%
data1
# Out:
# array([ 0.14369678,  0.94466663, -1.86361298, ...,  1.27028492,
#         2.26004243,  0.81289113])

# %%
data2
# Out:
# array([-0.02333372,  3.31417212,  1.10459789, ...,  3.24478603,
#        -1.00070521,  3.48790258])

# %%
plt.hist([data1, data2], bins = 20, color = ['r', 'b'], label = ['dist1', 'dist2'])
plt.xlabel("Values")
plt.ylabel('frequency')
plt.title("stacked histogram")
plt.show()

# %%
#scatterplot >> to understand the relationship between two features
x = np.random.rand(50)
y = np.random.rand(50)
x
# Out:
# array([0.25782024, 0.74770117, 0.34475043, 0.01688951, 0.47060606,
#        0.99120322, 0.94724742, 0.60572558, 0.59285188, 0.28100831,
#        0.34475493, 0.21651983, 0.43801719, 0.88039416, 0.56331874,
#        0.3526702 , 0.48366639, 0.89544687, 0.52556568, 0.04594589,
#        0.40597869, 0.27939849, 0.7600128 , 0.06607109, 0.10021472,
#        0.59295931, 0.34868705, 0.86567517, 0.64936242, 0.0818939 ,
#        0.54677903, 0.63275101, 0.78452396, 0.22058302, 0.98032864,
#        0.43503138, 0.13442569, 0.34124842, 0.84968092, 0.42695151,
#        0.87682166, 0.6502579 , 0.3427373 , 0.1744129 , 0.72786088,
#        0.64612126, 0.00279279, 0.72805299, 0.85179211, 0.21097619])

# %%
y
# Out:
# array([0.65551223, 0.51817007, 0.48441147, 0.84980607, 0.0728593 ,
#        0.00903926, 0.86566024, 0.67063604, 0.76571643, 0.69366086,
#        0.28811382, 0.40719065, 0.55359483, 0.12953712, 0.17996382,
#        0.46741952, 0.04802515, 0.68844324, 0.03781545, 0.25821918,
#        0.11976774, 0.32883732, 0.96318788, 0.16978073, 0.58226212,
#        0.93821636, 0.36543545, 0.28278904, 0.79614563, 0.4045457 ,
#        0.32939981, 0.46111651, 0.43365681, 0.16446396, 0.49200791,
#        0.56317719, 0.27783827, 0.79386952, 0.61786268, 0.50791267,
#        0.01754788, 0.07377483, 0.41175236, 0.53461385, 0.03164215,
#        0.58135348, 0.74145508, 0.70420551, 0.00853419, 0.32270037])

# %%
plt.scatter(x, y, c = 'r', marker = "X")

# %%
#bar plot >> To see the districution of categorical variables
x = ["a", "b", "c","d"] #name of students
y = [4, 6, 1, 10] #no of days present in the class

plt.bar(x, y, color = 'r') #vertical plot
# Out:
# <BarContainer object of 4 artists>

# %%
x = ["a", "b", "c","d"] #name of students
y = [4, 6, 1, 10] #no of days present in the class

plt.barh(x, y, color = 'r') #horizontal plot
# Out:
# <BarContainer object of 4 artists>

# %%
#pie char >> To understand the percent distribution of data
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%")
plt.title("Pie chart")
plt.show()

# %%
#focus on one segment
explode = (0.0, 0.1, 0.1)
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%", explode = explode)
plt.title("Pie chart")
plt.show()

# %%
explode = (0.0, 0.1, 0.1)
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%", explode = explode, shadow = True)
plt.title("Pie chart")
plt.show()

# %%
#3d plot >> 3 dimesion plot
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c='red')

# %%
data = pd.read_csv("Bank_Churn.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
plt.scatter(x = data['Age'], y=data["Balance"])

# %%
data.plot.scatter(x = 'Age', y = 'Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(data['Age'], color = 'red')
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Balance'], color = 'red')
# Out:
# (array([3.623e+03, 6.900e+01, 3.600e+02, 1.173e+03, 2.081e+03, 1.747e+03,
#         7.290e+02, 1.860e+02, 3.000e+01, 2.000e+00]),
#  array([     0.   ,  25089.809,  50179.618,  75269.427, 100359.236,
#         125449.045, 150538.854, 175628.663, 200718.472, 225808.281,
#         250898.09 ]),
#  <BarContainer object of 10 artists>)

# %%
#Boxplot  >> to check the distribution of data and outliers(extreme/abnormal values)
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x244b9e71790>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x244b1f10850>,
#  'cmins': <matplotlib.collections.LineCollection at 0x244b9e8e9d0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x244b8b9e490>}

# %% [raw]
# #area plot >> variables changed over time
# An area plot, also called a stacked area plot, is a type of data visualization that shows how
# various quantitative factors have changed over time while highlighting how they all work together to form the whole. It's particularly good for illustrating how elements of a whole change over time or along a continuous dimension.
# A layered representation of the data is produced in an area plot by layering many variables on top of one another. The cumulative influence of all levels provides insight into the overall trend. Each layer represents a separate category or variable.
# To distinguish between categories, the space beneath each layer is frequently colored.

# %%
years = [2021, 2018, 2022, 2023, 2017]
category1 = [20, 25, 30, 28, 35]
category2 = [10, 15, 20, 18, 25]
category3 = [5, 8, 10, 9, 15]

plt.stackplot(years, category1, category2, category3, labels = ["category1", "category2", "category3",],
             colors = ["skyblue","lightgreen", "orange"])
plt.xlabel("years")
plt.ylabel("Values")
plt.title("Area plot")
plt.legend()
plt.show()
